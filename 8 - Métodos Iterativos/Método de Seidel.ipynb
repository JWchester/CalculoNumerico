# %% [markdown]
# ## BIBLIOTECAS

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
from IPython.display import Math

# %% [markdown]
# ## FUNÇÕES

# %%
def print_latex(eq):
    return display(Math(eq))

# %%
matrizDosCoeficientes = np.array([[12,-1,-1],[-1,12,-2],[-1,-2,12]]).astype(float)
matrizDasVariaveis = []
matrizResultante = np.array([[10],[9],[14]]).astype(float)

#inserindo operadores para representação matricial
caracterEspace1 = np.array(["*"])
caracterEspace2 = np.array(["="])

#ajusta elementos para o print
for i in range(len(matrizDosCoeficientes)):
    caracterEspace1 = np.insert(caracterEspace1,0,'​')
    caracterEspace2 = np.insert(caracterEspace2,0,'​')
    matrizDasVariaveis.append(["x{}".format(i+1)])

tabela = [[tabulate(matrizDosCoeficientes, tablefmt='heavy_grid'),tabulate(caracterEspace1,tablefmt='plain'), tabulate(matrizDasVariaveis, tablefmt='heavy_grid'), tabulate(caracterEspace2,tablefmt='plain'), tabulate(matrizResultante, tablefmt='heavy_grid')]]
print(tabulate(tabela, headers=[], tablefmt='plain'))
# Out:
# ┏━━━━┳━━━━┳━━━━┓  ​   ┏━━━━┓  ​   ┏━━━━┓
# ┃ 12 ┃ -1 ┃ -1 ┃  ​   ┃ x1 ┃  ​   ┃ 10 ┃
# ┣━━━━╋━━━━╋━━━━┫  ​   ┣━━━━┫  ​   ┣━━━━┫
# ┃ -1 ┃ 12 ┃ -2 ┃  *  ┃ x2 ┃  =  ┃  9 ┃
# ┣━━━━╋━━━━╋━━━━┫     ┣━━━━┫     ┣━━━━┫
# ┃ -1 ┃ -2 ┃ 12 ┃     ┃ x3 ┃     ┃ 14 ┃
# ┗━━━━┻━━━━┻━━━━┛     ┗━━━━┛     ┗━━━━┛

# %%
a = ""
for i in range(len(matrizDosCoeficientes)):
    pivo = matrizDosCoeficientes[i][i]
    a = f'|a_{{{str(i+1)+str(i+1)}}}| >'
    b = f'|{matrizDosCoeficientes[i][i]}| >'
    c = abs(matrizDosCoeficientes[i][i])
    c1 = 0
    for j in range(len(matrizDosCoeficientes[0])):
        if i != j:
            a = a + f" |a_{{{str(i+1)+str(j+1)}}}|+"
            b = b + f'|{matrizDosCoeficientes[i][j]}|+'
            c1 = c1 + abs(matrizDosCoeficientes[i][j])
    a = a[:-1]
    b = b[:-1]
    resultado = f'{a} \u2192 \hspace{{0.5cm}} {b} \hspace{{0.5cm}} {c}{" < " + str(c1) if c < c1 else " > " + str(c1)}'
    print_latex(resultado)
    if '<' in resultado:
        print('a condição de pivo maior que a soma dos elementos da mesma linha não foi satisfeita. selecione novos elementos!')
        raise SystemExit("")
    else:
        continue
# Out:
# $\displaystyle |a_{11}| > |a_{12}|+ |a_{13}| → \hspace{0.5cm} |12.0| >|-1.0|+|-1.0| \hspace{0.5cm} 12.0 > 2.0$
# $\displaystyle |a_{22}| > |a_{21}|+ |a_{23}| → \hspace{0.5cm} |12.0| >|-1.0|+|-2.0| \hspace{0.5cm} 12.0 > 3.0$
# $\displaystyle |a_{33}| > |a_{31}|+ |a_{32}| → \hspace{0.5cm} |12.0| >|-1.0|+|-2.0| \hspace{0.5cm} 12.0 > 3.0$

# %%
for i in range(len(matrizDosCoeficientes)):
    pivo = matrizDosCoeficientes[i][i]
    matrizDosCoeficientes[i][i] = 0
    for j in range(len(matrizDosCoeficientes[0])):
        if i!=j:
            matrizDosCoeficientes[i][j] = matrizDosCoeficientes[i][j]/pivo
    matrizResultante[i] = matrizResultante[i]/pivo


tabela = [[tabulate(matrizDosCoeficientes, tablefmt='heavy_grid'),tabulate(caracterEspace1,tablefmt='plain'), tabulate(matrizDasVariaveis, tablefmt='heavy_grid'), tabulate(caracterEspace2,tablefmt='plain'), tabulate(matrizResultante, tablefmt='heavy_grid')]]
print(tabulate(tabela, headers=[], tablefmt='plain'))
# Out:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┓  ​   ┏━━━━┓  ​   ┏━━━━━━━━━━┓
# ┃  0         ┃ -0.0833333 ┃ -0.0833333 ┃  ​   ┃ x1 ┃  ​   ┃ 0.833333 ┃
# ┣━━━━━━━━━━━━╋━━━━━━━━━━━━╋━━━━━━━━━━━━┫  ​   ┣━━━━┫  ​   ┣━━━━━━━━━━┫
# ┃ -0.0833333 ┃  0         ┃ -0.166667  ┃  *  ┃ x2 ┃  =  ┃ 0.75     ┃
# ┣━━━━━━━━━━━━╋━━━━━━━━━━━━╋━━━━━━━━━━━━┫     ┣━━━━┫     ┣━━━━━━━━━━┫
# ┃ -0.0833333 ┃ -0.166667  ┃  0         ┃     ┃ x3 ┃     ┃ 1.16667  ┃
# ┗━━━━━━━━━━━━┻━━━━━━━━━━━━┻━━━━━━━━━━━━┛     ┗━━━━┛     ┗━━━━━━━━━━┛

# %%
#Aplicando a equação de Seidel

#atribuindo valor inicial para as variaveis: x1 = x2 = x3 = 0
parcial = 0
limite = 0
v_anterior = np.zeros(len(matrizDosCoeficientes))
matriz_tol = np.random.random(len(matrizDosCoeficientes))
r = np.random.random(len(matrizDosCoeficientes))
TABELADESGRAÇADA = []
for i in range(len(matrizDosCoeficientes)):
    matrizDasVariaveis[i] = 0
while limite!=30:
    for i in range(len(matrizDosCoeficientes)):
        parcial = matrizResultante[i]
        print(f'{parcial} ',end =" ")
        for j in range(len(matrizDosCoeficientes[0])):
            if i != j:
                print(f'- ({matrizDosCoeficientes[i][j]}) * ({matrizDasVariaveis[j]})',end=' ')
                parcial = parcial - matrizDosCoeficientes[i][j]*matrizDasVariaveis[j]

        print(f' = {parcial}',end=" ") #mostra o valor do xi atual encontrado
        print('\n\n')

        matriz_tol[i] = abs((parcial-v_anterior[i])/parcial)

        print(f"\n\n| ({parcial} - {v_anterior[i]})/{parcial} |\n\n")
        if abs((parcial-v_anterior[i])/parcial) <= 0.002:
            r[i] = matriz_tol[i]
            matrizDasVariaveis[i] = v_anterior[i]
            print(f'\n\n\n{r}\n\n\n')
            print(matrizDasVariaveis)
        else:
            r[i] = matriz_tol[i]
            print(f'\n\n\n{matriz_tol}\n\n\n')
            matrizDasVariaveis[i] = parcial
            v_anterior[i] = parcial
            print(matrizDasVariaveis)
        TABELADESGRAÇADA.append([f'x{i+1}',parcial,r[i]])

    if all(elemento < 0.002 for elemento in r):
      break
    else:
      pass
    limite = limite +1
    print(f'\n{limite}\n')
    resultadox = []
# Out:
# [0.83333333]  - (-0.08333333333333333) * (0) - (-0.08333333333333333) * (0)  = [0.83333333]
#
#
#
#
# | ([0.83333333] - 0.0)/[0.83333333] |
#
#
#
#
#
# [1.         0.27658046 0.23511434]
#
#
#
# [array([0.83333333]), 0, 0]
# [0.75]  - (-0.08333333333333333) * ([0.83333333]) - (-0.16666666666666666) * (0)  = [0.81944444]
#
#
#
#
# | ([0.81944444] - 0.0)/[0.81944444] |
#
#
#
#
#
# [1.         1.         0.23511434]
#
#
#
# [array([0.83333333]), array([0.81944444]), 0]
# [1.16666667]  - (-0.08333333333333333) * ([0.83333333]) - (-0.16666666666666666) * ([0.81944444])  = [1.37268519]
#
#
#
#
# | ([1.37268519] - 0.0)/[1.37268519] |
#
#
#
#
#
# [1. 1. 1.]
#
#
#
# [array([0.83333333]), array([0.81944444]), array([1.37268519])]
#
# 1
#
# [0.83333333]  - (-0.08333333333333333) * ([0.81944444]) - (-0.08333333333333333) * ([1.37268519])  = [1.0160108]
#
#
#
#
# | ([1.0160108] - 0.8333333333333334)/[1.0160108] |
#
#
#
#
#
# [0.17979875 1.         1.        ]
#
#
#
# [array([1.0160108]), array([0.81944444]), array([1.37268519])]
# [0.75]  - (-0.08333333333333333) * ([1.0160108]) - (-0.16666666666666666) * ([1.37268519])  = [1.06344843]
#
#
#
#
# | ([1.06344843] - 0.8194444444444444)/[1.06344843] |
#
#
#
#
#
# [0.17979875 0.229446   1.        ]
#
#
#
# [array([1.0160108]), array([1.06344843]), array([1.37268519])]
# [1.16666667]  - (-0.08333333333333333) * ([1.0160108]) - (-0.16666666666666666) * ([1.06344843])  = [1.42857564]
#
#
#
#
# | ([1.42857564] - 1.3726851851851851)/[1.42857564] |
#
#
#
#
#
# [0.17979875 0.229446   0.0391232 ]
#
#
#
# [array([1.0160108]), array([1.06344843]), array([1.42857564])]
#
# 2
#
# [0.83333333]  - (-0.08333333333333333) * ([1.06344843]) - (-0.08333333333333333) * ([1.42857564])  = [1.04100201]
#
#
#
#
# | ([1.04100201] - 1.0160108024691359)/[1.04100201] |
#
#
#
#
#
# [0.02400687 0.229446   0.0391232 ]
#
#
#
# [array([1.04100201]), array([1.06344843]), array([1.42857564])]
# [0.75]  - (-0.08333333333333333) * ([1.04100201]) - (-0.16666666666666666) * ([1.42857564])  = [1.07484611]
#
#
#
#
# | ([1.07484611] - 1.0634484310699588)/[1.07484611] |
#
#
#
#
#
# [0.02400687 0.01060401 0.0391232 ]
#
#
#
# [array([1.04100201]), array([1.07484611]), array([1.42857564])]
# [1.16666667]  - (-0.08333333333333333) * ([1.04100201]) - (-0.16666666666666666) * ([1.07484611])  = [1.43255785]
#
#
#
#
# | ([1.43255785] - 1.428575638717421)/[1.43255785] |
#
#
#
#
#
# [0.02400687 0.01060401 0.00277979]
#
#
#
# [array([1.04100201]), array([1.07484611]), array([1.43255785])]
#
# 3
#
# [0.83333333]  - (-0.08333333333333333) * ([1.07484611]) - (-0.08333333333333333) * ([1.43255785])  = [1.04228366]
#
#
#
#
# | ([1.04228366] - 1.041002005815615)/[1.04228366] |
#
#
#
#
#
# [0.00122966 0.01060401 0.00277979]
#
#
#
# [1.041002005815615, array([1.07484611]), array([1.43255785])]
# [0.75]  - (-0.08333333333333333) * (1.041002005815615) - (-0.16666666666666666) * ([1.43255785])  = [1.07550981]
#
#
#
#
# | ([1.07550981] - 1.0748461069375381)/[1.07550981] |
#
#
#
#
#
# [0.00122966 0.0006171  0.00277979]
#
#
#
# [1.041002005815615, 1.0748461069375381, array([1.43255785])]
# [1.16666667]  - (-0.08333333333333333) * (1.041002005815615) - (-0.16666666666666666) * (1.0748461069375381)  = [1.43255785]
#
#
#
#
# | ([1.43255785] - 1.4325578516408912)/[1.43255785] |
#
#
#
#
#
# [0.00122966 0.0006171  0.        ]
#
#
#
# [1.041002005815615, 1.0748461069375381, 1.4325578516408912]

# %%
numeros = [i + 1 for i in range(len(TABELADESGRAÇADA) // len(matrizDasVariaveis)) for _ in range(len(matrizDasVariaveis))]
for i, numero in enumerate(numeros):
    TABELADESGRAÇADA[i].insert(0, f'{numero}ª')
df = pd.DataFrame(TABELADESGRAÇADA)
for i in range(len(matrizDasVariaveis), len(TABELADESGRAÇADA) + (len(TABELADESGRAÇADA)//len(matrizDasVariaveis))+1, len(matrizDasVariaveis)+1):
    TABELADESGRAÇADA.insert(i, ["---------"] * len(TABELADESGRAÇADA[0]))
print(tabulate(TABELADESGRAÇADA,tablefmt='heavy_grid',headers=['iteração i','x_i+n','Resultado',f'tolerância(<={0.0002})']))
# Out:
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ iteração i   ┃ x_i+n     ┃ Resultado    ┃ tolerância(<=0.0002)   ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 1ª           ┃ x1        ┃ [0.83333333] ┃ 1.0                    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 1ª           ┃ x2        ┃ [0.81944444] ┃ 1.0                    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 1ª           ┃ x3        ┃ [1.37268519] ┃ 1.0                    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ ---------    ┃ --------- ┃ ---------    ┃ ---------              ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 2ª           ┃ x1        ┃ [1.0160108]  ┃ 0.17979874691475226    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 2ª           ┃ x2        ┃ [1.06344843] ┃ 0.22944599803491797    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 2ª           ┃ x3        ┃ [1.42857564] ┃ 0.0391232021724902     ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ ---------    ┃ --------- ┃ ---------    ┃ ---------              ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 3ª           ┃ x1        ┃ [1.04100201] ┃ 0.024006873384358973   ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 3ª           ┃ x2        ┃ [1.07484611] ┃ 0.010604007209975116   ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 3ª           ┃ x3        ┃ [1.43255785] ┃ 0.0027797920474267636  ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ ---------    ┃ --------- ┃ ---------    ┃ ---------              ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 4ª           ┃ x1        ┃ [1.04228366] ┃ 0.001229662753516452   ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 4ª           ┃ x2        ┃ [1.07550981] ┃ 0.000617104696118215   ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ 4ª           ┃ x3        ┃ [1.43255785] ┃ 0.0                    ┃
# ┣━━━━━━━━━━━━━━╋━━━━━━━━━━━╋━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━┫
# ┃ ---------    ┃ --------- ┃ ---------    ┃ ---------              ┃
# ┗━━━━━━━━━━━━━━┻━━━━━━━━━━━┻━━━━━━━━━━━━━━┻━━━━━━━━━━━━━━━━━━━━━━━━┛
